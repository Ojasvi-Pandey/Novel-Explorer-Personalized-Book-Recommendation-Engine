# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('books.csv')

# %%
df.head(10)
# Out:
#    bookID                                              title  \
# 0   34889  Brown's Star Atlas: Showing All The Bright Sta...
# 1   22128                     Patriots (The Coming Collapse)
# 2   16914                  The Tolkien Fan's Medieval Reader
# 3   12224  Streetcar Suburbs: The Process of Growth in Bo...
# 4    2034  Comoediae 1: Acharenses/Equites/Nubes/Vespae/P...
# 5    2560                  Willem de Kooning: Late Paintings
# 6    2843  Literature Circle Guide: Bridge to Terabithia:...
# 7    4287  Middlesex Borough (Images of America: New Jersey)
# 8   14741  Zone of the Enders: The 2nd Runner Official St...
# 9   17224  The Diamond Color Meditation: Color Pathway to...
#
#                                     authors  \
# 0                                     Brown
# 1                              James Wesley
# 2  David E. Smith (Turgon of TheOneRing.net
# 3                           Sam Bass Warner
# 4       Aristophanes/F.W. Hall/W.M. Geldart
# 5           Julie Sylvester/David Sylvester
# 6                            Tara MacCarthy
# 7      Middlesex Borough Heritage Committee
# 8                                Tim Bogenn
# 9                             John  Diamond
#
#                                       average_rating        isbn      isbn13  \
# 0                                     Son & Ferguson           0   851742718
# 1                                             Rawles        3.63  156384155X
# 2   one of the founding members of this Tolkien w...        3.58  1593600119
# 3                                  Jr./Sam B. Warner        3.58   674842111
# 4                                                  5   198145047    9.78E+12
# 5                                                  5  382960226X    9.78E+12
# 6                                                  5   439271711    9.78E+12
# 7                                                  5   738511676    9.78E+12
# 8                                                  5   744002354    9.78E+12
# 9                                                  5  1890995525    9.78E+12
#
#   language_code num_pages  ratings_count  text_reviews_count publication_date  \
# 0      9.78E+12       eng             49                   0                0
# 1      9.78E+12       eng            342                  38                4
# 2      9.78E+12       eng            400                  26                4
# 3      9.78E+12     en-US            236                  61                6
# 4           grc       364              0                   0        2/22/1922
# 5           eng        83              1                   0       09-01-2006
# 6           eng        32              4                   1       01-01-2002
# 7           eng       128              2                   0        3/17/2003
# 8           eng       128              2                   0       03-06-2003
# 9           eng        74              5                   3       02-01-2006
#
#                       publisher                  Unnamed: 12
# 0                    05-01-1977    Brown Son & Ferguson Ltd.
# 1                     1/15/1999  Huntington House Publishers
# 2                    04-06-2004            Cold Spring Press
# 3                     4/20/2004     Harvard University Press
# 4  Oxford University Press  USA                          NaN
# 5                Schirmer Mosel                          NaN
# 6            Teaching Resources                          NaN
# 7            Arcadia Publishing                          NaN
# 8                    BradyGames                          NaN
# 9         Square One Publishers                          NaN

# %%
df=df.drop(['Unnamed: 12'], axis=1)

# %%
df.tail(10)
# Out:
#        bookID                                              title  \
# 11117   28467                   Sclerotherapy and vein treatment
# 11118   29091                           The Berlin Phenomenology
# 11119   29404       Your Child and Jesus: A Family Activity Book
# 11120   30080                  Beckett Football Card Price Guide
# 11121   36946      Random House Crossword Mega Omnibus  Volume 1
# 11122   37467  Classroom Interactions as Cross-Cultural Encou...
# 11123   41044                                      Day and Night
# 11124   42758  The Fantastic Vampire: Studies in the Children...
# 11125   44705  The Leadership Challenge: Skills for Taking Ch...
# 11126   45259  Anthony Thwaite: In Conversation With Peter Da...
#
#                                                  authors average_rating  \
# 11117  Robert A. Weiss/Margaret A. Weiss/Karen L. Bea...              0
# 11118   Georg Wilhelm Friedrich Hegel/Michael John Petry              0
# 11119                          Rick Osborne/Kevin Miller              0
# 11120                         Dan Hitt/James Beckett III              0
# 11121                         United Feature Syndication              0
# 11122                    Jasmine C.M. Luk/Angel M.Y. Lin              0
# 11123                           Better Homes and Gardens              0
# 11124                                  James Craig Holte              0
# 11125                                   Warren G. Bennis              0
# 11126  Peter  Dale/Ian          Hamilton/Anthony Thwaite              0
#
#              isbn    isbn13 language_code num_pages  ratings_count  \
# 11117    71485422  9.78E+12           eng       248              0
# 11118  9027712050  9.79E+12           eng       210              0
# 11119  080242855X  9.78E+12           eng       112              0
# 11120  1930692471  9.78E+12           eng       830              0
# 11121  081292763X  9.78E+12           eng       336              0
# 11122   805850848  9.78E+12           eng       241              0
# 11123   696018829  9.78E+12           eng        32              0
# 11124   313309337  9.78E+12           eng       176              0
# 11125  088684049X  9.78E+12           eng        60              0
# 11126   953284123  9.78E+12           eng        96              0
#
#        text_reviews_count publication_date  \
# 11117                   0       12/30/2011
# 11118                   0        5/31/1981
# 11119                   0        9/13/1999
# 11120                   0       09-01-2006
# 11121                   0        7/22/1997
# 11122                   0       08-05-2006
# 11123                   1       03-01-1989
# 11124                   0        3/30/2002
# 11125                   0       12-01-1985
# 11126                   0       12-09-1999
#
#                                  publisher
# 11117  McGraw-Hill Professional Publishing
# 11118                             Springer
# 11119                     Moody Publishers
# 11120                        Beckett Media
# 11121         Random House Puzzles & Games
# 11122                            Routledge
# 11123                 Meredith Corporation
# 11124                      Greenwood Press
# 11125      AMR/Advanced Management Reports
# 11126        Between the Lines Productions

# %%
df.isnull().sum()
# Out:
# bookID                0
# title                 0
# authors               0
# average_rating        0
# isbn                  0
# isbn13                0
# language_code         0
# num_pages             0
# ratings_count         0
# text_reviews_count    0
# publication_date      0
# publisher             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11127 entries, 0 to 11126
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11127 non-null  int64
#  1   title               11127 non-null  object
#  2   authors             11127 non-null  object
#  3   average_rating      11127 non-null  object
#  4   isbn                11127 non-null  object
#  5   isbn13              11127 non-null  object
#  6   language_code       11127 non-null  object
#  7   num_pages           11127 non-null  object
#  8   ratings_count       11127 non-null  int64
#  9   text_reviews_count  11127 non-null  int64
#  10  publication_date    11127 non-null  object
#  11  publisher           11127 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#              bookID  ratings_count  text_reviews_count
# count  11127.000000   1.112700e+04        11127.000000
# mean   21310.938887   1.793649e+04          541.864474
# std    13093.358023   1.124794e+05         2576.174610
# min        1.000000   0.000000e+00            0.000000
# 25%    10287.000000   1.040000e+02            9.000000
# 50%    20287.000000   7.450000e+02           47.000000
# 75%    32104.500000   4.993500e+03          237.500000
# max    45641.000000   4.597666e+06        94265.000000

# %%
top_ten=df[df['ratings_count']>1000000]
top_ten=top_ten.sort_values(by='ratings_count', ascending=False).head(10)
top_ten_rating=top_ten.sort_values(by='average_rating', ascending=False)

# %%
plt.barh(top_ten_rating['title'], top_ten_rating['average_rating'], color='green')
plt.xlabel('Average Rating')
plt.ylabel('Title')
plt.title('Top Ten Rating by Title')
plt.show()

# %%
book_aut=df.groupby('authors')['title'].count().reset_index().sort_values('title', ascending=False).head(10).set_index('authors')
print(book_aut)
# Out:
#                              title
# authors
# P.G. Wodehouse                  40
# Stephen King                    40
# Rumiko Takahashi                39
# Orson Scott Card                35
# Agatha Christie                 33
# Piers Anthony                   30
# Mercedes Lackey                 29
# Sandra Brown                    29
# Dick Francis                    28
# Margaret Weis/Tracy Hickman     23

# %%
plt.figure(figsize=(5, 5))
plt.pie(book_aut['title'], labels=book_aut.index, autopct='%1.1f%%', startangle=90)
plt.title('Top 10 Authors by Number of Books')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Define a color palette with different colors
colors = plt.cm.tab10(np.arange(len(book_aut)))
plt.figure(figsize=(10, 6))
book_aut['title'].plot(kind='bar', color=colors)
plt.title('Top 10 Authors by Number of Books')
plt.xlabel('Authors')
plt.ylabel('Number of Books')
plt.tight_layout()
plt.show()

# %%
# Group by 'publisher' and count the number of books
publisher_counts = df.groupby('publisher')['title'].count().reset_index()
# Sort the publishers by the number of books in descending order
publisher_counts = publisher_counts.sort_values('title', ascending=False).head(10).set_index('publisher')
print(publisher_counts)
# Out:
#                   title
# publisher
# Vintage             318
# Penguin Books       261
# Penguin Classics    184
# Mariner Books       150
# Ballantine Books    144
# HarperCollins       112
# Harper Perennial    112
# Pocket Books        111
# Bantam              110
# VIZ Media LLC        88

# %%
# Create a pie chart

top_publishers = publisher_counts.head(10)

plt.figure(figsize=(5, 5))
plt.pie(top_publishers['title'], labels=top_publishers.index, autopct='%1.1f%%',startangle=90)
plt.title('Top 10 Publishers by Number of Books')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
top_publishers = publisher_counts.head(10)
num_publishers = len(top_publishers)
colors = plt.cm.tab10(np.linspace(0, 1, num_publishers))

plt.figure(figsize=(10, 6))

# Create a bar plot using the custom color palette
plt.bar(top_publishers.index, top_publishers['title'], color=colors)

plt.title('Top 10 Publishers by Number of Books')
plt.xlabel('Publishers')
plt.ylabel('Number of Books')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df=df.sort_values('average_rating').reset_index()
df=df.iloc[4:]
df
# Out:
#        index  bookID                                              title  \
# 4      11103    1302                     Juiced Official Strategy Guide
# 5      11104    3351           Open City 6: The Only Woman He Ever Left
# 6      11105    9337  How To Meditate: An Anthology Of Talks On Medi...
# 7      11106    9338         Insights: Talks On The Nature Of Existence
# 8      11107   10200                Venac sonetnih venaca; Puževa srma
# ...      ...     ...                                                ...
# 11122     21   36853                 Tyrannosaurus Wrecks (Stanley  #1)
# 11123     23   39580  The American Campaign: U.S. Presidential Campa...
# 11124     24   39829  His Princess Devotional: A Royal Encounter Wit...
# 11125     13   19788  The Goon Show  Volume 11: He's Fallen in the W...
# 11126     22   38804      The Irish Anatomist: A Study of Flann O'Brien
#
#                                                  authors average_rating  \
# 4                                             Doug Walsh              0
# 5      Open City Magazine/James Purdy/Daniel Pinchbec...              0
# 6                                      Frederick P. Lenz              0
# 7                                      Frederick P. Lenz              0
# 8                                           Dobrica Erić              0
# ...                                                  ...            ...
# 11122  Laura Driscoll/Alisa Klayman-Grodsky/Eric     ...              5
# 11123                                  James E. Campbell              5
# 11124                                Sheri Rose Shepherd              5
# 11125                                         NOT A BOOK              5
# 11126                                      Keith Donohue              5
#
#              isbn    isbn13 language_code num_pages  ratings_count  \
# 4       744005612  9.78E+12           eng       112              0
# 5      189044717X  9.78E+12           eng       200              0
# 6      1932206108  9.78E+12           eng       228              0
# 7      1932206086  9.78E+12           eng       304              0
# 8      8644101277  9.79E+12           srp       222              0
# ...           ...       ...           ...       ...            ...
# 11122   786845031  9.78E+12           eng        24              2
# 11123  089096940X  9.78E+12           eng       314              0
# 11124  1590529626  9.78E+12           eng       240              2
# 11125   563388323  9.78E+12           eng         2              2
# 11126  1930901356  9.78E+12           eng       222              1
#
#        text_reviews_count publication_date  \
# 4                       0       06-01-2005
# 5                       0       10/13/2000
# 6                       0       01-01-2004
# 7                       0       01-01-2003
# 8                       0       01-01-1996
# ...                   ...              ...
# 11122                   1       02-01-2003
# 11123                   0       05-01-2000
# 11124                   0       10/16/2007
# 11125                   0       10-02-1995
# 11126                   0        7/25/2003
#
#                                                publisher
# 4                                             BradyGames
# 5                           Grove Press  Open City Books
# 6      Frederick P. Lenz Foundation for American Budd...
# 7      Frederick P. Lenz Foundation for American Budd...
# 8                         Izdavačka agencija "Draganić"
# ...                                                  ...
# 11122                                       Disney Press
# 11123                         Texas A&M University Press
# 11124                                          Multnomah
# 11125                                 BBC Physical Audio
# 11126                                    Academica Press
#
# [11123 rows x 13 columns]

# %%
# Convert 'average_rating' column to float
df['average_rating'] = df['average_rating'].astype(float)

# Create figure and axis objects
fig, ax = plt.subplots(figsize=[10,10])

# Plot the distribution using Matplotlib's hist function
ax.hist(df['average_rating'], bins=30, color='purple', edgecolor='black', alpha=0.7)

# Set title and labels
ax.set_title('Average Rating Distribution for All Books')
ax.set_xlabel('Average Rating')
ax.set_ylabel('Frequency')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,10))

# Create a scatter plot using plt.scatter()
plt.scatter(data=df, x="average_rating", y="ratings_count", color='r', s=100, alpha=0.7)

# Set title and labels
plt.title('Relation between Rating counts and avg rating')
plt.xlabel('Average Rating')
plt.ylabel('Ratings Count')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df[['average_rating', 'num_pages', 'ratings_count']].corr(), annot=True, cmap='Spectral', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 4 to 11126
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               11123 non-null  int64
#  1   bookID              11123 non-null  int64
#  2   title               11123 non-null  object
#  3   authors             11123 non-null  object
#  4   average_rating      11123 non-null  float64
#  5   isbn                11123 non-null  object
#  6   isbn13              11123 non-null  object
#  7   language_code       11123 non-null  object
#  8   num_pages           11123 non-null  object
#  9   ratings_count       11123 non-null  int64
#  10  text_reviews_count  11123 non-null  int64
#  11  publication_date    11123 non-null  object
#  12  publisher           11123 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df=df.sort_values('num_pages', ascending=False).reset_index()
df=df.iloc[4:]
df.head(10)
# Out:
#     level_0  index  bookID                                              title  \
# 4      6562   4499   16619                               Democracy in America
# 5     10327    837   28389                              Marcel Proust: A Life
# 6     10719    438   19809  The Last Lion: Winston Spencer Churchill: Visi...
# 7     10715    437   19808  The Last Lion: Winston Spencer Churchill: Visi...
# 8      7026   4039   19670                      Debt of Honor (Jack Ryan  #7)
# 9       893  10253   34307                                      Aches & Pains
# 10     5249   5813    7015                          A Midsummer Night's Dream
# 11    10138   1028   31580                                In Search of Duende
# 12    10521    632   44921                                 Explode the Code 1
# 13     1751   9425   24978                                         Inside Job
#
#                                               authors  average_rating  \
# 4   Alexis de Tocqueville/Isaac Kramnick/Gerald Bevan            4.02
# 5                                   William C. Carter            4.33
# 6                                  William Manchester            4.42
# 7                                  William Manchester            4.42
# 8                                          Tom Clancy            4.05
# 9                             Maeve Binchy/Wendy Shea            3.53
# 10                      William Shakespeare/Roma Gill            3.94
# 11    Federico García Lorca/Norman Thomas di Giovanni            4.30
# 12                                         Nancy Hall            4.37
# 13                                      Connie Willis            3.67
#
#           isbn    isbn13 language_code num_pages  ratings_count  \
# 4    140447601  9.78E+12           eng       992          18925
# 5    300094000  9.78E+12           eng       992             14
# 6    385313489  9.78E+12           eng       992           9659
# 7    316545031  9.78E+12         en-US       992            335
# 8    425147584  9.78E+12           eng       990          39521
# 9    385335105  9.78E+12         en-US        99            356
# 10   198320213  9.78E+12           eng        99             14
# 11   811213765  9.78E+12           eng        99            616
# 12   838814603  9.78E+12           eng        99             89
# 13  1596060247  9.78E+12           eng        99           1442
#
#     text_reviews_count publication_date                     publisher
# 4                  523        4/24/2003              Penguin Classics
# 5                    4       02-08-2002         Yale University Press
# 6                  467       04-01-1984                         Delta
# 7                   38        5/30/1983       Little  Brown & Company
# 8                  469       08-01-1995                 Berkley Books
# 9                   30        6/13/2000               Delacorte Press
# 10                   3        8/15/2002  Oxford University Press  USA
# 11                  36        4/17/1998                New Directions
# 12                  10       01-01-2001   School Specialty Publishing
# 13                 180       06-01-2005            Subterranean Press

# %%
df.num_pages=df.num_pages.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11119 entries, 4 to 11122
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   level_0             11119 non-null  int64
#  1   index               11119 non-null  int64
#  2   bookID              11119 non-null  int64
#  3   title               11119 non-null  object
#  4   authors             11119 non-null  object
#  5   average_rating      11119 non-null  float64
#  6   isbn                11119 non-null  object
#  7   isbn13              11119 non-null  object
#  8   language_code       11119 non-null  object
#  9   num_pages           11119 non-null  float64
#  10  ratings_count       11119 non-null  int64
#  11  text_reviews_count  11119 non-null  int64
#  12  publication_date    11119 non-null  object
#  13  publisher           11119 non-null  object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.2+ MB

# %%
plt.figure(figsize=(10,6))

# Create a scatter plot 
plt.scatter(df['average_rating'], df['num_pages'],color='y', s=100, alpha=0.7)

# Set title and labels
plt.title('Relation between Average Rating and Number of Pages')
plt.xlabel('Average Rating')
plt.ylabel('Number of Pages')

# Show the plot
plt.show()

# %%
df2=df.copy()

# %%
df2.loc[(df2['average_rating']>=0)&(df2['average_rating']<=1),'rating between']="between 0 and 1"
df2.loc[(df2['average_rating']>1)&(df2['average_rating']<=2),'rating between']="between 1 and 2"
df2.loc[(df2['average_rating']>2)&(df2['average_rating']<=3),'rating between']="between 2 and 3"
df2.loc[(df2['average_rating']>3)&(df2['average_rating']<=4),'rating between']="between 3 and 4"
df2.loc[(df2['average_rating']>4)&(df2['average_rating']<=5),'rating between']="between 4 and 5"

# %%
df2.sort_values('average_rating')
# Out:
#        level_0  index  bookID  \
# 10787       20  11119   29404
# 6600        13  11112   24010
# 1160        12  11111   19257
# 7625        23  11122   37467
# 7507        18  11117   28467
# ...        ...    ...     ...
# 8297     11126     22   38804
# 7823     11122     21   36853
# 8802     11112     10   17830
# 10526    11110      8   14741
# 1598     11118     17   23552
#
#                                                    title  \
# 10787       Your Child and Jesus: A Family Activity Book
# 6600          Laguna  I Love You: The Best of "Our Town"
# 1160   Canopy: A Work for Voice and Light in Harvard ...
# 7625   Classroom Interactions as Cross-Cultural Encou...
# 7507                    Sclerotherapy and vein treatment
# ...                                                  ...
# 8297       The Irish Anatomist: A Study of Flann O'Brien
# 7823                  Tyrannosaurus Wrecks (Stanley  #1)
# 8802   Bulgakov's the Master and Margarita: The Text ...
# 10526  Zone of the Enders: The 2nd Runner Official St...
# 1598                         The New Big Book of America
#
#                                                  authors  average_rating  \
# 10787                          Rick Osborne/Kevin Miller             0.0
# 6600                           John Weld/Phil Interlandi             0.0
# 1160   David   Ward/Parveen Adams/Seamus Heaney/Ivan ...             0.0
# 7625                     Jasmine C.M. Luk/Angel M.Y. Lin             0.0
# 7507   Robert A. Weiss/Margaret A. Weiss/Karen L. Bea...             0.0
# ...                                                  ...             ...
# 8297                                       Keith Donohue             5.0
# 7823   Laura Driscoll/Alisa Klayman-Grodsky/Eric     ...             5.0
# 8802                                     Elena N. Mahlow             5.0
# 10526                                         Tim Bogenn             5.0
# 1598                                Todd Davis/Marc Frey             5.0
#
#              isbn    isbn13 language_code  num_pages  ratings_count  \
# 10787  080242855X  9.78E+12           eng      112.0              0
# 6600   1564741575  9.78E+12           eng      285.0              0
# 1160    916724948  9.78E+12           eng       63.0              0
# 7625    805850848  9.78E+12           eng      241.0              0
# 7507     71485422  9.78E+12           eng      248.0              0
# ...           ...       ...           ...        ...            ...
# 8297   1930901356  9.78E+12           eng      222.0              1
# 7823    786845031  9.78E+12           eng       24.0              2
# 8802    533017424  9.78E+12           eng      202.0              4
# 10526   744002354  9.78E+12           eng      128.0              2
# 1598    762412631  9.78E+12           eng       56.0              2
#
#        text_reviews_count publication_date  \
# 10787                   0        9/13/1999
# 6600                    0       03-01-1996
# 1160                    0       12/31/1997
# 7625                    0       08-05-2006
# 7507                    0       12/30/2011
# ...                   ...              ...
# 8297                    0        7/25/2003
# 7823                    1       02-01-2003
# 8802                    0       01-01-1975
# 10526                   0       03-06-2003
# 1598                    1        3/21/2002
#
#                                  publisher   rating between
# 10787                     Moody Publishers  between 0 and 1
# 6600                         Fithian Press  between 0 and 1
# 1160                     Arts Publications  between 0 and 1
# 7625                             Routledge  between 0 and 1
# 7507   McGraw-Hill Professional Publishing  between 0 and 1
# ...                                    ...              ...
# 8297                       Academica Press  between 4 and 5
# 7823                          Disney Press  between 4 and 5
# 8802                         Vantage Press  between 4 and 5
# 10526                           BradyGames  between 4 and 5
# 1598                         Courage Books  between 4 and 5
#
# [11119 rows x 15 columns]

# %%
rating_df=pd.get_dummies(df2['rating between'])
language_df=pd.get_dummies(df2['language_code'])

# %%
language_df
# Out:
#          ale    ara  en-CA  en-GB  en-US    eng    enm    fre    ger    gla  \
# 4      False  False  False  False  False   True  False  False  False  False
# 5      False  False  False  False  False   True  False  False  False  False
# 6      False  False  False  False  False   True  False  False  False  False
# 7      False  False  False  False   True  False  False  False  False  False
# 8      False  False  False  False  False   True  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11118  False  False  False  False  False   True  False  False  False  False
# 11119  False  False  False  False  False   True  False  False  False  False
# 11120  False  False  False  False  False   True  False  False  False  False
# 11121  False  False  False  False   True  False  False  False  False  False
# 11122  False  False  False  False  False   True  False  False  False  False
#
#        ...     nl    nor    por    rus    spa    srp    swe    tur    wel  \
# 4      ...  False  False  False  False  False  False  False  False  False
# 5      ...  False  False  False  False  False  False  False  False  False
# 6      ...  False  False  False  False  False  False  False  False  False
# 7      ...  False  False  False  False  False  False  False  False  False
# 8      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 11118  ...  False  False  False  False  False  False  False  False  False
# 11119  ...  False  False  False  False  False  False  False  False  False
# 11120  ...  False  False  False  False  False  False  False  False  False
# 11121  ...  False  False  False  False  False  False  False  False  False
# 11122  ...  False  False  False  False  False  False  False  False  False
#
#          zho
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# ...      ...
# 11118  False
# 11119  False
# 11120  False
# 11121  False
# 11122  False
#
# [11119 rows x 27 columns]

# %%
rating_df
# Out:
#        between 0 and 1  between 1 and 2  between 2 and 3  between 3 and 4  \
# 4                False            False            False            False
# 5                False            False            False            False
# 6                False            False            False            False
# 7                False            False            False            False
# 8                False            False            False            False
# ...                ...              ...              ...              ...
# 11118            False            False            False            False
# 11119            False            False            False            False
# 11120            False            False            False             True
# 11121            False            False            False            False
# 11122            False            False            False            False
#
#        between 4 and 5
# 4                 True
# 5                 True
# 6                 True
# 7                 True
# 8                 True
# ...                ...
# 11118             True
# 11119             True
# 11120            False
# 11121             True
# 11122             True
#
# [11119 rows x 5 columns]

# %%
feature=pd.concat([rating_df, language_df, df2['average_rating'], df2['ratings_count']], axis=1)

# %%
feature
# Out:
#        between 0 and 1  between 1 and 2  between 2 and 3  between 3 and 4  \
# 4                False            False            False            False
# 5                False            False            False            False
# 6                False            False            False            False
# 7                False            False            False            False
# 8                False            False            False            False
# ...                ...              ...              ...              ...
# 11118            False            False            False            False
# 11119            False            False            False            False
# 11120            False            False            False             True
# 11121            False            False            False            False
# 11122            False            False            False            False
#
#        between 4 and 5    ale    ara  en-CA  en-GB  en-US  ...    por    rus  \
# 4                 True  False  False  False  False  False  ...  False  False
# 5                 True  False  False  False  False  False  ...  False  False
# 6                 True  False  False  False  False  False  ...  False  False
# 7                 True  False  False  False  False   True  ...  False  False
# 8                 True  False  False  False  False  False  ...  False  False
# ...                ...    ...    ...    ...    ...    ...  ...    ...    ...
# 11118             True  False  False  False  False  False  ...  False  False
# 11119             True  False  False  False  False  False  ...  False  False
# 11120            False  False  False  False  False  False  ...  False  False
# 11121             True  False  False  False  False   True  ...  False  False
# 11122             True  False  False  False  False  False  ...  False  False
#
#          spa    srp    swe    tur    wel    zho  average_rating  ratings_count
# 4      False  False  False  False  False  False            4.02          18925
# 5      False  False  False  False  False  False            4.33             14
# 6      False  False  False  False  False  False            4.42           9659
# 7      False  False  False  False  False  False            4.42            335
# 8      False  False  False  False  False  False            4.05          39521
# ...      ...    ...    ...    ...    ...    ...             ...            ...
# 11118  False  False  False  False  False  False            4.05              1
# 11119  False  False  False  False  False  False            4.04              7
# 11120  False  False  False  False  False  False            3.89              2
# 11121  False  False  False  False  False  False            4.16             68
# 11122  False  False  False  False  False  False            4.26            214
#
# [11119 rows x 34 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

minmax=MinMaxScaler()

feature=minmax.fit_transform(feature)

# %%
feature
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.04000000e-01, 4.11621897e-03],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.66000000e-01, 3.04502328e-06],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.84000000e-01, 2.10084856e-03],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 7.78000000e-01, 4.35003326e-07],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.32000000e-01, 1.47901131e-05],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#         0.00000000e+00, 8.52000000e-01, 4.65453558e-05]])

# %%
from sklearn import neighbors
from sklearn.model_selection import train_test_split

model=neighbors.NearestNeighbors(n_neighbors=8)

model.fit(feature)

dist, idlist=model.kneighbors(feature)

# %%
dist
# Out:
# array([[0.00000000e+00, 5.98129566e-05, 3.70840335e-04, ...,
#         9.54397296e-04, 1.06706316e-03, 1.20539422e-03],
#        [0.00000000e+00, 0.00000000e+00, 1.08768270e-06, ...,
#         1.74005754e-06, 2.39255301e-06, 2.39255301e-06],
#        [0.00000000e+00, 2.19676778e-05, 2.80359644e-04, ...,
#         7.23410531e-04, 1.29174238e-03, 1.52164163e-03],
#        ...,
#        [0.00000000e+00, 2.17985195e-07, 4.34950576e-07, ...,
#         1.52269162e-06, 2.60995870e-06, 3.26250367e-06],
#        [2.98023224e-08, 1.52269162e-06, 5.65510356e-06, ...,
#         2.78402267e-05, 4.52403524e-05, 9.85282582e-05],
#        [0.00000000e+00, 4.34950576e-07, 2.61012884e-06, ...,
#         1.15275868e-05, 1.63126136e-05, 1.71826220e-05]])

# %%
idlist
# Out:
# array([[    0,  2032,  4328, ...,   255,  1734,   880],
#        [    1,  7814,  3899, ...,  1595,  5622,  5634],
#        [    2,   301,  4790, ...,  4564,  1723,   417],
#        ...,
#        [11116,  4786,  1082, ...,  4119,   520,  8431],
#        [11117, 10764, 10834, ...,  5422,  3119,   153],
#        [11118,  7262,  5816, ...,  4372,  4749,  5349]], dtype=int64)

# %%
def bookRecom(name):
    book_list=[]
    book_id=df2[df2['title']==name].index
    book_id=book_id[0]
    for new in idlist[book_id]:
        book_list.append(df2.loc[new].title)
    return book_list

# %%
#book_name = input("Enter the title of the book: ")
# recommended_books = bookRecom(book_name)

# %%
recommended_books = bookRecom('The Trail of Tears')

# %%
# Print the recommended book list
print("Recommended books:")
for book in recommended_books:
    print(book)
# Out:
# Recommended books:
# The New Big Book of America
# The Trail of Tears
# Have Space Suit—Will Travel
# Ocean Star Express
# Searching for God Knows What
# Comoediae 1: Acharenses/Equites/Nubes/Vespae/Pax/Aves
# Uncle Setnakt's Essential Guide to the Left Hand Path
# Bloody Bones (Anita Blake  Vampire Hunter #5)
